# %%
import pandas as pd

data_extracted_by_LLM = pd.read_csv('https://raw.githubusercontent.com/KhiemDangLe/Final-Project/main/raw_data_extracted_by_LLM.csv')
raw_data = pd.read_csv('https://raw.githubusercontent.com/KhiemDangLe/Final-Project/main/raw_full_detail_data.csv')

# %%
raw_data.head()
# Out:
#                                            page_link  \
# 0  https://batdongsan.vn/chua-toi-30trm2-hang-ngo...
# 1  https://batdongsan.vn/ban-nha-hxh-au-co-phuong...
# 2  https://batdongsan.vn/sat-mat-tien-phan-dang-l...
# 3  https://batdongsan.vn/chu-gap-ban-truoc-tet-le...
# 4  https://batdongsan.vn/luy-ban-bichtan-phu-dien...
#
#                                                title  article_id   category  \
# 0  Chưa tới 30tr/m2 - Hàng ngộp bank BAO ĐẦU TƯ ...    285164.0  Nhà riêng
# 1  Bán nhà HXH Âu Cơ Phường 9 Tân Bình, 51m2 3 Tầ...    285163.0  Nhà riêng
# 2  SÁT MẶT TIỀN PHAN ĐĂNG LƯU, PHƯỜNG 7, PHÚ NHUẬ...    285162.0        Nhà
# 3  CHỦ GẤP BÁN TRƯỚC TẾT LÊ HỒNG PHONG QUẬN 5 RA ...    285161.0  Nhà riêng
# 4  LŨY BÁN BÍCH,TÂN PHÚ-DIỆN TÍCH KHỦNG 96M2 ( 4....    285159.0  Nhà riêng
#
#          phone   district date_posted          price   area  bedroom   wc  \
# 0  933670051.0     Nhà Bè  2023-12-10  3899000000 tỷ  150.0      2.0  1.0
# ...

# %%
data_extracted_by_LLM.head()
# Out:
#   article_id  alleyway_property  under_mortgage  residential_purpose  \
# 0   285164.0                1.0             1.0                  1.0
# 1   285163.0                1.0             NaN                  1.0
# 2   285162.0                NaN             NaN                  1.0
# 3   285161.0                NaN             NaN                  1.0
# 4   285159.0                1.0             NaN                  1.0
#
#   numbers_of_floors  has_rooftop  furnished           street_name   0
# 0                 2          0.0        0.0                   NaN NaN
# 1                 3          NaN        NaN             Hẻm Âu Cơ NaN
# 2                 2          NaN        NaN         Phan Đăng Lưu NaN
# 3                 2          NaN        NaN         Lê Hồng Phong NaN
# 4                 2          NaN        0.0  LŨY BÁN BÍCH,TÂN PHÚ NaN

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12060 entries, 0 to 12059
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   page_link          12060 non-null  object
#  1   title              12053 non-null  object
#  2   article_id         12053 non-null  float64
#  3   category           12053 non-null  object
#  4   phone              12049 non-null  float64
#  5   district           12053 non-null  object
#  6   date_posted        12053 non-null  object
#  7   price              12053 non-null  object
#  8   area               10947 non-null  float64
#  9   bedroom            7116 non-null   float64
#  10  wc                 6787 non-null   float64
#  11  direction          1597 non-null   object
#  12  balcony_direction  1035 non-null   object
#  13  description        12053 non-null  object
# dtypes: float64(5), object(9)
# memory usage: 1.3+ MB

# %%
data_extracted_by_LLM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12052 entries, 0 to 12051
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   article_id           12037 non-null  object
#  1   alleyway_property    6440 non-null   float64
#  2   under_mortgage       2066 non-null   float64
#  3   residential_purpose  11719 non-null  float64
#  4   numbers_of_floors    10011 non-null  object
#  5   has_rooftop          4294 non-null   float64
#  6   furnished            3555 non-null   float64
#  7   street_name          11427 non-null  object
#  8   0                    0 non-null      float64
# dtypes: float64(6), object(3)
# memory usage: 847.5+ KB

# %%
# drop 0 columns
data_extracted_by_LLM.drop(columns=['0'], inplace=True)

# %%
# change article_id to string
for i in range(len(data_extracted_by_LLM['article_id'])):
    data_extracted_by_LLM['article_id'][i] = str(int(data_extracted_by_LLM['article_id'][i]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 3
#       1 # change article_id to string
#       2 for i in range(len(data_extracted_by_LLM['article_id'])):
# ----> 3     data_extracted_by_LLM['article_id'][i] = str(int(data_extracted_by_LLM['article_id'][i]))
#
# ValueError: invalid literal for int() with base 10: '285164.0'

# %%
data_extracted_by_LLM['article_id'][1]
# Out:
# '285163.0'

# %%
raw_data.head()
# Remove float values in article_id
# Out:
#                                            page_link  \
# 0  https://batdongsan.vn/chua-toi-30trm2-hang-ngo...
# 1  https://batdongsan.vn/ban-nha-hxh-au-co-phuong...
# 2  https://batdongsan.vn/sat-mat-tien-phan-dang-l...
# 3  https://batdongsan.vn/chu-gap-ban-truoc-tet-le...
# 4  https://batdongsan.vn/luy-ban-bichtan-phu-dien...
#
#                                                title  \
# 0  Chưa tới 30tr/m2 - Hàng ngộp bank BAO ĐẦU TƯ ...
# 1  Bán nhà HXH Âu Cơ Phường 9 Tân Bình, 51m2 3 Tầ...
# 2  SÁT MẶT TIỀN PHAN ĐĂNG LƯU, PHƯỜNG 7, PHÚ NHUẬ...
# 3  CHỦ GẤP BÁN TRƯỚC TẾT LÊ HỒNG PHONG QUẬN 5 RA ...
# 4  LŨY BÁN BÍCH,TÂN PHÚ-DIỆN TÍCH KHỦNG 96M2 ( 4....
#
#                                           article_id   category        phone  \
# 0  0        285164.0\n1        285163.0\n2       ...  Nhà riêng  933670051.0
# 1  0        285164.0\n1        285163.0\n2       ...  Nhà riêng  922351398.0
# 2  0        285164.0\n1        285163.0\n2       ...        Nhà  907340956.0
# ...

# %%
data_extracted_by_LLM.shape
raw_data.shape
# Out:
# (12060, 14)

# %%
raw_data['article_id'].nunique()
# Out:
# 12034

# %%
data_extracted_by_LLM['article_id'].nunique()
# Out:
# 12001

# %%
raw_data.merge(data_extracted_by_LLM , how = 'inner', on='article_id')
# Out:
#                                               page_link  \
# 0     https://batdongsan.vn/chua-toi-30trm2-hang-ngo...
# 1     https://batdongsan.vn/chua-toi-30trm2-hang-ngo...
# 2     https://batdongsan.vn/chua-toi-30trm2-hang-ngo...
# 3     https://batdongsan.vn/chua-toi-30trm2-hang-ngo...
# 4     https://batdongsan.vn/chua-toi-30trm2-hang-ngo...
# ...                                                 ...
# 5888  https://batdongsan.vn/du-an-khu-dan-cu-cho-vai...
# 5889  https://batdongsan.vn/du-an-khu-dan-cu-cho-vai...
# 5890  https://batdongsan.vn/du-an-khu-dan-cu-cho-vai...
# 5891  https://batdongsan.vn/du-an-khu-dan-cu-cho-vai...
# 5892  https://batdongsan.vn/ban-nha-hem-o-to-duong-q...
#
#                                                   title article_id   category  \
# 0     Chưa tới 30tr/m2 - Hàng ngộp bank BAO ĐẦU TƯ ...   285164.0  Nhà riêng
# 1     Chưa tới 30tr/m2 - Hàng ngộp bank BAO ĐẦU TƯ ...   285164.0  Nhà riêng
# ...

# %%
merged_data.shape
# Out:
# (5893, 21)
